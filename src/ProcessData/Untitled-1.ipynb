# %%
client = MongoClient(
    "mongodb+srv://dataintergration:nhom10@cluster0.hqw7c.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

database = client['DataIntegration']

ap_collections = database['anphat']

# %%
import json

# %%
f = open('test.json')

# %%
data = json.load(f)

# %%
'Hãng sản xuất' in data[0]['device_detail_infor'][7]
# Out:
# True

# %%
set(len(data[0]['device_detail_infor']) for x in data)
# Out:
# {169,
#  171,
#  173,
#  175,
#  177,
#  179,
#  181,
#  185,
#  201,
#  205,
#  207,
#  209,
#  211,
#  213,
#  215,
#  217,
#  317,
#  333}

# %%
data[0]['device_detail_infor']
# Out:
# ['Tên đầy đủ',
#  'Email',
#  'Điện thoại',
#  'Thông tin liên hệ',
#  '\n            ',
#  '\n            ',
#  '\n          ',
#  'Hãng sản xuất\xa0\xa0',
#  '\xa0',
#  'Laptop Acer',
#  'Tên sản phẩm',
#  'Laptop Acer Gaming Predator Triton 300 PT315-53-77CV NH.QDQSV.002',
#  'Nhóm thuộc tính',
#  'Laptop',
#  '\xa0|\xa0',
#  'Laptop gmaing',
#  ' |\xa0',
#  'Acer Predator Gaming',
#  ' |\xa0',
#  'Laptop RTX 30 SERIES',
#  'Bộ vi xử lý',
#  '\xa0',
#  'Bộ vi xử lý',
#  'Intel® Core™ i7-11800H',
#  'Tốc độ',
#  '2.30 GHz\xa0',
#  'upto 4.60 GHz, 8 cores 16 threads',
#  'Bộ nhớ đệm',
#  '24MB Cache',
#  'Bộ nhớ trong (RAM)',
#  'Dung lượng',
#  '16GB (8x2GB)\xa0',
#  'DDR4 3200MHz',
#  'Số khe cắm',
#  '2 khe, tối đa 32GB',
#  'Ổ cứng\xa0',
#  'Dung lượng',
#  '512GB PCIe NVMe SED SSD',
#  'Tốc độ vòng quay',
#  '\xa0',
#  'Khe cắm SSD mở rộng',
#  'Có h',
#  'ỗ trợ khe cắm SSD M.2',
#  ' ',
#  '(đã cắm sẵn 512GB, nâng cấp tối đa 2TB NVMe, RAID 0 SSD)',
#  'Ổ đĩa quang (ODD)\xa0',
#  '\xa0Không',
#  'Hiển thị\xa0',
#  'Màn hình',
#  '15.6inch QHD IPS 165Hz SlimBezel',
#  'Độ phân giải',
#  ' QHD 2560 x1440',
#  'Đồ Họa (VGA)\xa0',
#  'Card màn hình',
#  'NVIDIA® GeForce® RTX 3060 with 6GB of dedicated GDDR6 VRAM',
#  'Kết nối (Network)\xa0',
#  'Wireless',
#  '• Killer Wi-Fi 6 AX 1650i',
#  '• 802.11 a/b/g/n+acR2+ax wireless LAN',
#  '• Dual Band (2.4 GHz and 5 GHz)',
#  '• 2x2 MU-MIMO technology',
#  'LAN',
#  '• Killer Ethernet E2600',
#  '• 10/100/1000 Mbps',
#  '• Hibernation mode support',
#  '• Wake On Lan support',
#  '• IPv4 and IPv6 support',
#  'Bluetooth',
#  '\xa0• Supports Bluetooth® 5.1',
#  'Bàn phím , Chuột\xa0',
#  'Kiểu bàn phím',
#  'Bàn phím tiêu chuẩn -\xa0',
#  'RGB 4 zone, bàn phím số',
#  'Chuột',
#  'Cảm ứng đa điểm',
#  'Giao tiếp mở rộng\xa0',
#  'Kết nối USB',
#  '1 x USB Type-C port supporting:',
#  '• DisplayPort over USB-C',
#  '• Thunderbolt 4',
#  '1 x USB 3.2 Gen 2 port featuring power-off USB charging',
#  '2 x USB 3.2 Gen 1 ports',
#  '1 x Ethernet (RJ-45) port',
#  '1 x DC-in jack for AC adapter',
#  'Kết nối HDMI/VGA',
#  '1 x HDMI®2.1 port with HDCP support',
#  '1 x Mini DisplayPortTM 1.4',
#  'Tai nghe',
#  '1 x 3.5 mm headphone/speaker jack, supporting headsets with built-in',
#  'microphone',
#  'Camera',
#  '• 1280 x 720 resolution ',
#  '• 720p HD audio/video recording ',
#  '• High dynamic range imaging (HDR) ',
#  'Card mở rộng',
#  '\xa0',
#  'LOA',
#  '\xa0',
#  'Kiểu Pin',
#  '59 Wh 4-cell Li-ion battery',
#  'Cân nặng',
#  '2Kg',
#  'Kích thước',
#  '353 (W) x 255 (D) x 19.9 (H) mm',
#  'Sạc pin',
#  'Đi kèm',
#  'Hệ điều hành\xa0(bản quyền) đi kèm\xa0',
#  'Windows 11 Home\xa0',
#  'Màu sắc',
#  'Đen\xa0',
#  'Xuất Xứ',
#  'Trung Quốc',
#  'Hãng sản xuất\xa0\xa0',
#  '\xa0',
#  'Laptop Acer',
#  'Tên sản phẩm',
#  'Laptop Acer Gaming Predator Triton 300 PT315-53-77CV NH.QDQSV.002',
#  'Nhóm thuộc tính',
#  'Laptop',
#  '\xa0|\xa0',
#  'Laptop gmaing',
#  ' |\xa0',
#  'Acer Predator Gaming',
#  ' |\xa0',
#  'Laptop RTX 30 SERIES',
#  'Bộ vi xử lý',
#  '\xa0',
#  'Bộ vi xử lý',
#  'Intel® Core™ i7-11800H',
#  'Tốc độ',
#  '2.30 GHz\xa0',
#  'upto 4.60 GHz, 8 cores 16 threads',
#  'Bộ nhớ đệm',
#  '24MB Cache',
#  'Bộ nhớ trong (RAM)',
#  'Dung lượng',
#  '16GB (8x2GB)\xa0',
#  'DDR4 3200MHz',
#  'Số khe cắm',
#  '2 khe, tối đa 32GB',
#  'Ổ cứng\xa0',
#  'Dung lượng',
#  '512GB PCIe NVMe SED SSD',
#  'Tốc độ vòng quay',
#  '\xa0',
#  'Khe cắm SSD mở rộng',
#  'Có h',
#  'ỗ trợ khe cắm SSD M.2',
#  ' ',
#  '(đã cắm sẵn 512GB, nâng cấp tối đa 2TB NVMe, RAID 0 SSD)',
#  'Ổ đĩa quang (ODD)\xa0',
#  '\xa0Không',
#  'Hiển thị\xa0',
#  'Màn hình',
#  '15.6inch QHD IPS 165Hz SlimBezel',
#  'Độ phân giải',
#  ' QHD 2560 x1440',
#  'Đồ Họa (VGA)\xa0',
#  'Card màn hình',
#  'NVIDIA® GeForce® RTX 3060 with 6GB of dedicated GDDR6 VRAM',
#  'Kết nối (Network)\xa0',
#  'Wireless',
#  '• Killer Wi-Fi 6 AX 1650i',
#  '• 802.11 a/b/g/n+acR2+ax wireless LAN',
#  '• Dual Band (2.4 GHz and 5 GHz)',
#  '• 2x2 MU-MIMO technology',
#  'LAN',
#  '• Killer Ethernet E2600',
#  '• 10/100/1000 Mbps',
#  '• Hibernation mode support',
#  '• Wake On Lan support',
#  '• IPv4 and IPv6 support',
#  'Bluetooth',
#  '\xa0• Supports Bluetooth® 5.1',
#  'Bàn phím , Chuột\xa0',
#  'Kiểu bàn phím',
#  'Bàn phím tiêu chuẩn -\xa0',
#  'RGB 4 zone, bàn phím số',
#  'Chuột',
#  'Cảm ứng đa điểm',
#  'Giao tiếp mở rộng\xa0',
#  'Kết nối USB',
#  '1 x USB Type-C port supporting:',
#  '• DisplayPort over USB-C',
#  '• Thunderbolt 4',
#  '1 x USB 3.2 Gen 2 port featuring power-off USB charging',
#  '2 x USB 3.2 Gen 1 ports',
#  '1 x Ethernet (RJ-45) port',
#  '1 x DC-in jack for AC adapter',
#  'Kết nối HDMI/VGA',
#  '1 x HDMI®2.1 port with HDCP support',
#  '1 x Mini DisplayPortTM 1.4',
#  'Tai nghe',
#  '1 x 3.5 mm headphone/speaker jack, supporting headsets with built-in',
#  'microphone',
#  'Camera',
#  '• 1280 x 720 resolution ',
#  '• 720p HD audio/video recording ',
#  '• High dynamic range imaging (HDR) ',
#  'Card mở rộng',
#  '\xa0',
#  'LOA',
#  '\xa0',
#  'Kiểu Pin',
#  '59 Wh 4-cell Li-ion battery',
#  'Cân nặng',
#  '2Kg',
#  'Kích thước',
#  '353 (W) x 255 (D) x 19.9 (H) mm',
#  'Sạc pin',
#  'Đi kèm',
#  'Hệ điều hành\xa0(bản quyền) đi kèm\xa0',
#  'Windows 11 Home\xa0',
#  'Màu sắc',
#  'Đen\xa0',
#  'Xuất Xứ',
#  'Trung Quốc']

# %%
import pandas as pd

# %%
data = pd.read_html('https://www.anphatpc.com.vn/laptop-lenovo-thinkpad-e15-gen-3-20yg00ajva.html',encoding='utf8')

# %%
data = data[1]

# %%
data.drop(index=data[data[0] == data[1]].index,inplace=True)

# %%
data
# Out:
#                                   0  \
# 0                     Hãng sản xuất
# 1                      Tên sản phẩm
# 2                       Dòng Laptop
# 4                     Công nghệ CPU
# 5                           Số nhân
# 6                          Số luồng
# 7                        Tốc độ CPU
# 8                     Tốc độ tối đa
# 9                        Bộ nhớ đệm
# 11                              RAM
# 12                         Loại RAM
# 13                   Tốc độ Bus RAM
# 14                       Số khe cắm
# 15                Hỗ trợ RAM tối đa
# 17                       Dung lượng
# 18                 Tốc độ vòng quay
# 19              Khe cắm SSD mở rộng
# 20                Ổ đĩa quang (ODD)
# 22              Kích thước màn hình
# 23                     Độ phân giải
# 24                      Tần số quét
# 25               Công nghệ màn hình
# 27                    Card màn hình
# 29                         Wireless
# 30                              LAN
# 31                        Bluetooth
# 33                    Kiểu bàn phím
# 34                            Chuột
# 36                      Kết nối USB
# 37                 Kết nối HDMI/VGA
# 38                         Tai nghe
# 39                           Camera
# 40                     Card mở rộng
# 41                              LOA
# 42                         Kiểu Pin
# 43                          Sạc pin
# 44  Hệ điều hành (bản quyền) đi kèm
# 45    Kích thước (Dài x Rộng x Cao)
# 46                      Trọng Lượng
# 47                          Màu sắc
# 48                          Xuất Xứ
#
#                                                     1
# 0                                       Laptop Lenovo
# 1                Lenovo ThinkPad E15 Gen 3 20YG00AJVA
# 2   Laptop | Laptop Văn Phòng | Laptop Ryzen 5 | L...
# 4                                  AMD Ryzen™ 5-5500U
# 5                                                   6
# 6                                                  12
# 7                                              2.1GHz
# 8                                              4.0GHz
# 9                                                 8MB
# 11                         8GB Soldered + 1 khe trống
# 12                                               DDR4
# 13                                            3200MHz
# 14                                              1 khe
# 15                               Nâng cấp tối đa 24GB
# 17                 512GB SSD M.2 2242 PCIe 3.0x4 NVMe
# 18                                                NaN
# 19                                                  -
# 20                                           Không có
# 22                                          15.6 inch
# 23                                  FHD (1920 x 1080)
# 24                                                  -
# 25                             IPS 300nits Anti-glare
# 27                     Integrated AMD Radeon Graphics
# 29                                RTL8822CE 11ac, 2x2
# 30                                          100/1000M
# 31                                              BT5.0
# 33                                Bàn phím tiêu chuẩn
# 34                                    Cảm ứng đa điểm
# 36  1x USB 2.01x USB 3.2 Gen 1 (Always On)1x USB-C...
# 37                                       1x HDMI 1.4b
# 38       1x Headphone / microphone combo jack (3.5mm)
# 39                          720p with Privacy Shutter
# 40                                                  -
# 41                                              2 Loa
# 42                                       3 Cell, 45Wh
# 43                                             Đi kèm
# 44                                            FreeDos
# 45                                365 x 240 x 18.9 mm
# 46                                             1.7 kg
# 47                                                Đen
# 48                                         Trung Quốc

# %%
import numpy as np

# %%
list_type = ['Tên sản phẩm','Hệ điều hành\xa0(bản quyền) đi kèm','Dung lượng','Bộ vi xử lý','Card màn hình','Dung lượng','Trọng Lượng','Xuất xứ','Hãng sản xuất','Màu sắc','Kiểu Pin']

# %%
dict_tmp = {'Tên sản phẩm':'product_name','Hệ điều hành\xa0(bản quyền) đi kèm':'os','Bộ vi xử lý':'cpu','Card màn hình':'gpu','Trọng Lượng':'weight','Xuất xứ':'origin','Hãng sản xuất':'brand','Màu sắc':'color','Kiểu Pin':'pin'}

# %%
dict_tmp.values()
# Out:
# dict_values(['product_name', 'os', 'cpu', 'gpu', 'weight', 'origin', 'brand', 'color', 'pin'])

# %%
dict_loader = {}
for x in dict_tmp.values():
    dict_loader[x] = ''

# %%
flags = 0
for id, item in data.iterrows():
    if (item[0] == 'Dung lượng' and item[1][2:4] == 'GB') or item[0] == 'RAM':
        dict_loader['ram'] = item[1]
    elif item[0] == 'Dung lượng' and item[1][2:4] != 'GB':
        dict_loader['storage'] = item[1]
    elif item[0] == 'Công nghệ CPU':
        dict_loader['cpu'] = item[1]
    elif item[0] == 'Xuất Xứ':
        dict_loader['origin'] = item[1]
    elif item[0] in list_type:
        dict_loader[dict_tmp[item[0]]] = item[1]

# %%
dict_loader
# Out:
# {'product_name': 'Lenovo ThinkPad E15 Gen 3 20YG00AJVA',
#  'os': 'FreeDos',
#  'cpu': 'AMD Ryzen™ 5-5500U',
#  'gpu': 'Integrated AMD Radeon Graphics',
#  'weight': '1.7 kg',
#  'origin': 'Trung Quốc',
#  'brand': 'Laptop Lenovo',
#  'color': 'Đen',
#  'pin': '3 Cell, 45Wh',
#  'ram': '8GB Soldered + 1 khe trống',
#  'storage': '512GB SSD M.2 2242 PCIe 3.0x4 NVMe'}

# %%
np.where(data[0].values == 'Hãng sản xuất')[0]
# Out:
# array([0], dtype=int64)
